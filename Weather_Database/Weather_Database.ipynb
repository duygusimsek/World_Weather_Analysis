# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create a list for holding the cities.
cities=[]
#identify the nearest city for each latitide and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 758

# %%
#Import the requests library
import requests
#Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Cloudiness": city_clouds,
                            "Humidity": city_humidity,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Wind Speed": city_wind,
                            "Weather Description":city_weather_desc})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pacific grove
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | ibipeba
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | jieshi
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | teya
# Processing Record 10 of Set 1 | port hedland
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | twin falls
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | albina
# Processing Record 16 of Set 1 | lagoa
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | prince rupert
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | gallup
# Processing Record 24 of Set 1 | ekhabi
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | labytnangi
# Processing Record 27 of Set 1 | marystown
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | fukue
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | kaitangata
# Processing Record 32 of Set 1 | okhotsk
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | ballina
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | union city
# Processing Record 38 of Set 1 | sztum
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | bosaso
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | naples
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | shetpe
# Processing Record 3 of Set 2 | biltine
# Processing Record 4 of Set 2 | samarai
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | amazar
# Processing Record 8 of Set 2 | gonbad-e qabus
# Processing Record 9 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 2 | rio grande
# Processing Record 11 of Set 2 | qasigiannguit
# Processing Record 12 of Set 2 | chardara
# Processing Record 13 of Set 2 | biak
# Processing Record 14 of Set 2 | george town
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | tautira
# Processing Record 18 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 2 | ligayan
# Processing Record 20 of Set 2 | arlit
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | verkhoyansk
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | ambovombe
# Processing Record 27 of Set 2 | acapulco
# Processing Record 28 of Set 2 | zadar
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | melk
# Processing Record 31 of Set 2 | port-cartier
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | lavrentiya
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | vila franca do campo
# Processing Record 37 of Set 2 | saurimo
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | san cristobal
# Processing Record 40 of Set 2 | kita
# Processing Record 41 of Set 2 | polczyn-zdroj
# Processing Record 42 of Set 2 | mareeba
# Processing Record 43 of Set 2 | roald
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | turukhansk
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | sorong
# Processing Record 50 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | roma
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | anadyr
# Processing Record 8 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 3 | basoko
# Processing Record 10 of Set 3 | zhob
# Processing Record 11 of Set 3 | popondetta
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | goure
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | saint anthony
# Processing Record 16 of Set 3 | tessalit
# Processing Record 17 of Set 3 | high rock
# Processing Record 18 of Set 3 | beyneu
# Processing Record 19 of Set 3 | fort saint james
# Processing Record 20 of Set 3 | puerto plata
# Processing Record 21 of Set 3 | greencastle
# Processing Record 22 of Set 3 | manzhouli
# Processing Record 23 of Set 3 | yar-sale
# Processing Record 24 of Set 3 | krasnoarmeysk
# Processing Record 25 of Set 3 | yulara
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | cuamba
# Processing Record 29 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 3 | kisangani
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | grindavik
# Processing Record 34 of Set 3 | bajah
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | victor harbor
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | gobabis
# Processing Record 40 of Set 3 | ushtobe
# Processing Record 41 of Set 3 | kirksville
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | saiha
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | bandarbeyla
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | pocone
# Processing Record 48 of Set 3 | mukhtolovo
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | butaritari
# Processing Record 1 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 2 of Set 4 | alice town
# Processing Record 3 of Set 4 | porto santo
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 4 | fort smith
# Processing Record 6 of Set 4 | lexington
# Processing Record 7 of Set 4 | inirida
# Processing Record 8 of Set 4 | bukachacha
# Processing Record 9 of Set 4 | cao bang
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | puerto suarez
# Processing Record 13 of Set 4 | krasnoborsk
# Processing Record 14 of Set 4 | weinan
# Processing Record 15 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 4 | gabu
# Processing Record 17 of Set 4 | kendari
# Processing Record 18 of Set 4 | mogosesti
# Processing Record 19 of Set 4 | isla vista
# Processing Record 20 of Set 4 | dingle
# Processing Record 21 of Set 4 | poyarkovo
# Processing Record 22 of Set 4 | ciudad bolivar
# Processing Record 23 of Set 4 | muravlenko
# Processing Record 24 of Set 4 | the pas
# Processing Record 25 of Set 4 | siavonga
# Processing Record 26 of Set 4 | porto novo
# Processing Record 27 of Set 4 | pechory
# Processing Record 28 of Set 4 | clyde river
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | port blair
# Processing Record 32 of Set 4 | san policarpo
# Processing Record 33 of Set 4 | kahului
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | port alfred
# Processing Record 37 of Set 4 | vostok
# Processing Record 38 of Set 4 | severodvinsk
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | kautokeino
# Processing Record 41 of Set 4 | isiro
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | taltal
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | filadelfia
# Processing Record 47 of Set 4 | mizoch
# Processing Record 48 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 4 | shubarshi
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | salalah
# Processing Record 2 of Set 5 | marsh harbour
# Processing Record 3 of Set 5 | gizo
# Processing Record 4 of Set 5 | dikson
# Processing Record 5 of Set 5 | port macquarie
# Processing Record 6 of Set 5 | skjervoy
# Processing Record 7 of Set 5 | micheweni
# Processing Record 8 of Set 5 | plettenberg bay
# Processing Record 9 of Set 5 | silvan
# Processing Record 10 of Set 5 | buala
# Processing Record 11 of Set 5 | hofn
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | faanui
# Processing Record 14 of Set 5 | kenai
# Processing Record 15 of Set 5 | laguna
# Processing Record 16 of Set 5 | svetlyy
# Processing Record 17 of Set 5 | atherton
# Processing Record 18 of Set 5 | antofagasta
# Processing Record 19 of Set 5 | hobyo
# Processing Record 20 of Set 5 | progreso
# Processing Record 21 of Set 5 | port moresby
# Processing Record 22 of Set 5 | manokwari
# Processing Record 23 of Set 5 | upernavik
# Processing Record 24 of Set 5 | sur
# Processing Record 25 of Set 5 | timmins
# Processing Record 26 of Set 5 | dunedin
# Processing Record 27 of Set 5 | west richland
# Processing Record 28 of Set 5 | mnogovershinnyy
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | macas
# Processing Record 31 of Set 5 | tocopilla
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | berlevag
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | san patricio
# Processing Record 36 of Set 5 | nanortalik
# Processing Record 37 of Set 5 | mitu
# Processing Record 38 of Set 5 | sandpoint
# Processing Record 39 of Set 5 | buluang
# Processing Record 40 of Set 5 | lorengau
# Processing Record 41 of Set 5 | bereda
# Processing Record 42 of Set 5 | cam ranh
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | iralaya
# Processing Record 45 of Set 5 | stulovo
# Processing Record 46 of Set 5 | gouyave
# Processing Record 47 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | beisfjord
# Processing Record 50 of Set 5 | meulaboh
# Processing Record 1 of Set 6 | pontian kecil
# Processing Record 2 of Set 6 | batemans bay
# Processing Record 3 of Set 6 | kusti
# Processing Record 4 of Set 6 | vanimo
# Processing Record 5 of Set 6 | mercedes
# Processing Record 6 of Set 6 | poum
# Processing Record 7 of Set 6 | senno
# Processing Record 8 of Set 6 | adelanto
# Processing Record 9 of Set 6 | mar del plata
# Processing Record 10 of Set 6 | lebork
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | otjiwarongo
# Processing Record 13 of Set 6 | korla
# Processing Record 14 of Set 6 | zholymbet
# Processing Record 15 of Set 6 | stornoway
# Processing Record 16 of Set 6 | upington
# Processing Record 17 of Set 6 | aswan
# Processing Record 18 of Set 6 | veraval
# Processing Record 19 of Set 6 | tecoanapa
# Processing Record 20 of Set 6 | paamiut
# Processing Record 21 of Set 6 | mehamn
# Processing Record 22 of Set 6 | kolomak
# Processing Record 23 of Set 6 | isangel
# Processing Record 24 of Set 6 | lidkoping
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | severnyy
# Processing Record 28 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 6 | aklavik
# Processing Record 30 of Set 6 | camacha
# Processing Record 31 of Set 6 | westport
# Processing Record 32 of Set 6 | general roca
# Processing Record 33 of Set 6 | mayo
# Processing Record 34 of Set 6 | jabinyanah
# Processing Record 35 of Set 6 | tateyama
# Processing Record 36 of Set 6 | ramsar
# Processing Record 37 of Set 6 | eureka
# Processing Record 38 of Set 6 | afsin
# Processing Record 39 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 6 | boyolangu
# Processing Record 41 of Set 6 | naifaru
# Processing Record 42 of Set 6 | jiuquan
# Processing Record 43 of Set 6 | crucea
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | qeshm
# Processing Record 46 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | astana
# Processing Record 48 of Set 6 | xichang
# Processing Record 49 of Set 6 | nordfjordeid
# Processing Record 50 of Set 6 | prado
# Processing Record 1 of Set 7 | kaeo
# Processing Record 2 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | sorland
# Processing Record 5 of Set 7 | jose bonifacio
# Processing Record 6 of Set 7 | vestmanna
# Processing Record 7 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 7 | shaoyang
# Processing Record 9 of Set 7 | bouca
# Processing Record 10 of Set 7 | comodoro rivadavia
# Processing Record 11 of Set 7 | saskylakh
# Processing Record 12 of Set 7 | vostochnyy
# Processing Record 13 of Set 7 | karrapur
# Processing Record 14 of Set 7 | arica
# Processing Record 15 of Set 7 | portland
# Processing Record 16 of Set 7 | hamilton
# Processing Record 17 of Set 7 | kamaishi
# Processing Record 18 of Set 7 | coahuayana
# Processing Record 19 of Set 7 | san quintin
# Processing Record 20 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 21 of Set 7 | drymen
# Processing Record 22 of Set 7 | nalut
# Processing Record 23 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 7 | ust-tsilma
# Processing Record 25 of Set 7 | flinders
# Processing Record 26 of Set 7 | asau
# Processing Record 27 of Set 7 | sinnamary
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | evansville
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | ancud
# Processing Record 32 of Set 7 | touros
# Processing Record 33 of Set 7 | vargem grande
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | timizart
# Processing Record 36 of Set 7 | vershino-shakhtaminskiy
# Processing Record 37 of Set 7 | tilichiki
# Processing Record 38 of Set 7 | chuy
# Processing Record 39 of Set 7 | sitka
# Processing Record 40 of Set 7 | ucluelet
# Processing Record 41 of Set 7 | dharchula
# Processing Record 42 of Set 7 | lethem
# Processing Record 43 of Set 7 | adrar
# Processing Record 44 of Set 7 | seabra
# Processing Record 45 of Set 7 | quatre cocos
# Processing Record 46 of Set 7 | port lincoln
# Processing Record 47 of Set 7 | pangnirtung
# Processing Record 48 of Set 7 | honiara
# Processing Record 49 of Set 7 | ust-maya
# Processing Record 50 of Set 7 | mandalgovi
# Processing Record 1 of Set 8 | kizukuri
# Processing Record 2 of Set 8 | verkhnyaya inta
# Processing Record 3 of Set 8 | vardo
# Processing Record 4 of Set 8 | bongandanga
# Processing Record 5 of Set 8 | aykhal
# Processing Record 6 of Set 8 | jiaozuo
# Processing Record 7 of Set 8 | rocha
# Processing Record 8 of Set 8 | tuatapere
# Processing Record 9 of Set 8 | matamoros
# Processing Record 10 of Set 8 | nyurba
# Processing Record 11 of Set 8 | ducheng
# Processing Record 12 of Set 8 | bereznik
# Processing Record 13 of Set 8 | tyukhtet
# Processing Record 14 of Set 8 | kamenka
# Processing Record 15 of Set 8 | kloulklubed
# Processing Record 16 of Set 8 | ayan
# Processing Record 17 of Set 8 | komsomolets
# Processing Record 18 of Set 8 | belle fourche
# Processing Record 19 of Set 8 | narsaq
# Processing Record 20 of Set 8 | mirzapur
# Processing Record 21 of Set 8 | fort nelson
# Processing Record 22 of Set 8 | nizhnevartovsk
# Processing Record 23 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 8 | bellevue
# Processing Record 25 of Set 8 | fairbanks
# Processing Record 26 of Set 8 | maniwaki
# Processing Record 27 of Set 8 | ganzhou
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | moron
# Processing Record 30 of Set 8 | ilo
# Processing Record 31 of Set 8 | achinsk
# Processing Record 32 of Set 8 | coos bay
# Processing Record 33 of Set 8 | rawah
# Processing Record 34 of Set 8 | monte santo
# Processing Record 35 of Set 8 | brandon
# Processing Record 36 of Set 8 | faya
# Processing Record 37 of Set 8 | maiduguri
# Processing Record 38 of Set 8 | nikolskoye
# Processing Record 39 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 40 of Set 8 | araguacu
# Processing Record 41 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 8 | nhulunbuy
# Processing Record 43 of Set 8 | lodwar
# Processing Record 44 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 8 | mykhaylivka
# Processing Record 46 of Set 8 | kjollefjord
# Processing Record 47 of Set 8 | whitefish
# Processing Record 48 of Set 8 | san lucas
# Processing Record 49 of Set 8 | dhidhdhoo
# Processing Record 50 of Set 8 | sydney
# Processing Record 1 of Set 9 | erenhot
# Processing Record 2 of Set 9 | port elizabeth
# Processing Record 3 of Set 9 | jeremie
# Processing Record 4 of Set 9 | sassandra
# Processing Record 5 of Set 9 | carutapera
# Processing Record 6 of Set 9 | bethel
# Processing Record 7 of Set 9 | port-gentil
# Processing Record 8 of Set 9 | amalapuram
# Processing Record 9 of Set 9 | kavaratti
# Processing Record 10 of Set 9 | guerrero negro
# Processing Record 11 of Set 9 | bowen
# Processing Record 12 of Set 9 | nishihara
# Processing Record 13 of Set 9 | torbay
# Processing Record 14 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 9 | hazleton
# Processing Record 16 of Set 9 | lerwick
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | salina
# Processing Record 19 of Set 9 | bam
# Processing Record 20 of Set 9 | nampula
# Processing Record 21 of Set 9 | perigueux
# Processing Record 22 of Set 9 | bonfim
# Processing Record 23 of Set 9 | baruun-urt
# Processing Record 24 of Set 9 | sao joao de pirabas
# Processing Record 25 of Set 9 | cannington
# Processing Record 26 of Set 9 | lata
# Processing Record 27 of Set 9 | murnau
# Processing Record 28 of Set 9 | poltava
# Processing Record 29 of Set 9 | sisimiut
# Processing Record 30 of Set 9 | devrek
# Processing Record 31 of Set 9 | tshikapa
# Processing Record 32 of Set 9 | wanning
# Processing Record 33 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 9 | sibolga
# Processing Record 35 of Set 9 | poshekhonye
# Processing Record 36 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 9 | lucapa
# Processing Record 38 of Set 9 | poronaysk
# Processing Record 39 of Set 9 | lar
# Processing Record 40 of Set 9 | imisli
# City not found. Skipping...
# Processing Record 41 of Set 9 | nome
# Processing Record 42 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 9 | praia da vitoria
# Processing Record 44 of Set 9 | darlowo
# Processing Record 45 of Set 9 | monduli
# Processing Record 46 of Set 9 | luderitz
# Processing Record 47 of Set 9 | alekseyevsk
# Processing Record 48 of Set 9 | kropotkin
# Processing Record 49 of Set 9 | saint-augustin
# Processing Record 50 of Set 9 | senneterre
# Processing Record 1 of Set 10 | codrington
# Processing Record 2 of Set 10 | ho chi minh city
# Processing Record 3 of Set 10 | selty
# Processing Record 4 of Set 10 | kiunga
# Processing Record 5 of Set 10 | tawang
# Processing Record 6 of Set 10 | hurricane
# Processing Record 7 of Set 10 | shiraz
# Processing Record 8 of Set 10 | half moon bay
# Processing Record 9 of Set 10 | yenagoa
# Processing Record 10 of Set 10 | lilongwe
# Processing Record 11 of Set 10 | shimoda
# Processing Record 12 of Set 10 | lazaro cardenas
# Processing Record 13 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 14 of Set 10 | kichera
# Processing Record 15 of Set 10 | cabra
# Processing Record 16 of Set 10 | lagos
# Processing Record 17 of Set 10 | sobolevo
# Processing Record 18 of Set 10 | nikolayevsk-na-amure
# Processing Record 19 of Set 10 | trim
# Processing Record 20 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 21 of Set 10 | vangaindrano
# Processing Record 22 of Set 10 | peniche
# Processing Record 23 of Set 10 | udgir
# Processing Record 24 of Set 10 | lompoc
# Processing Record 25 of Set 10 | lundazi
# Processing Record 26 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 10 | darnah
# Processing Record 28 of Set 10 | beringovskiy
# Processing Record 29 of Set 10 | san juan
# Processing Record 30 of Set 10 | pontianak
# Processing Record 31 of Set 10 | santa fe
# Processing Record 32 of Set 10 | kalmunai
# Processing Record 33 of Set 10 | mbaiki
# Processing Record 34 of Set 10 | knysna
# Processing Record 35 of Set 10 | guelavia
# City not found. Skipping...
# Processing Record 36 of Set 10 | conceicao do araguaia
# Processing Record 37 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 10 | saint-joseph
# Processing Record 39 of Set 10 | aksay
# Processing Record 40 of Set 10 | talnakh
# Processing Record 41 of Set 10 | krivodanovka
# Processing Record 42 of Set 10 | san mariano
# Processing Record 43 of Set 10 | jibuti
# Processing Record 44 of Set 10 | cascais
# Processing Record 45 of Set 10 | terra santa
# Processing Record 46 of Set 10 | dhuburi
# Processing Record 47 of Set 10 | karaton
# Processing Record 48 of Set 10 | caravelas
# Processing Record 49 of Set 10 | panaba
# Processing Record 50 of Set 10 | yerbogachen
# Processing Record 1 of Set 11 | vao
# Processing Record 2 of Set 11 | bireun
# Processing Record 3 of Set 11 | camopi
# Processing Record 4 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 11 | megion
# Processing Record 7 of Set 11 | opuwo
# Processing Record 8 of Set 11 | rundu
# Processing Record 9 of Set 11 | nawalapitiya
# Processing Record 10 of Set 11 | tiarei
# Processing Record 11 of Set 11 | kyra
# Processing Record 12 of Set 11 | mackay
# Processing Record 13 of Set 11 | bismarck
# Processing Record 14 of Set 11 | dwarka
# Processing Record 15 of Set 11 | aras
# Processing Record 16 of Set 11 | merauke
# Processing Record 17 of Set 11 | ust-kuyga
# Processing Record 18 of Set 11 | andenes
# Processing Record 19 of Set 11 | wamba
# Processing Record 20 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 11 | waingapu
# Processing Record 22 of Set 11 | cururupu
# Processing Record 23 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 11 | sao joao da barra
# Processing Record 25 of Set 11 | bonthe
# Processing Record 26 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 11 | kapit
# Processing Record 28 of Set 11 | monastyrshchina
# Processing Record 29 of Set 11 | kibaya
# Processing Record 30 of Set 11 | decatur
# Processing Record 31 of Set 11 | apomu
# Processing Record 32 of Set 11 | nouadhibou
# Processing Record 33 of Set 11 | hami
# Processing Record 34 of Set 11 | ingham
# Processing Record 35 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 11 | kirovsk
# Processing Record 37 of Set 11 | sovetskiy
# Processing Record 38 of Set 11 | charters towers
# Processing Record 39 of Set 11 | hvide sande
# Processing Record 40 of Set 11 | richards bay
# Processing Record 41 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 11 | riyadh
# Processing Record 43 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | barranca
# Processing Record 46 of Set 11 | hualmay
# Processing Record 47 of Set 11 | hetauda
# Processing Record 48 of Set 11 | dudinka
# Processing Record 49 of Set 11 | vilhena
# Processing Record 50 of Set 11 | xiongzhou
# Processing Record 1 of Set 12 | dongsheng
# Processing Record 2 of Set 12 | harboore
# Processing Record 3 of Set 12 | natchez
# Processing Record 4 of Set 12 | novyy urgal
# Processing Record 5 of Set 12 | takoradi
# Processing Record 6 of Set 12 | bac lieu
# Processing Record 7 of Set 12 | luan
# Processing Record 8 of Set 12 | buraydah
# Processing Record 9 of Set 12 | sangar
# Processing Record 10 of Set 12 | balaipungut
# Processing Record 11 of Set 12 | okha
# Processing Record 12 of Set 12 | aracati
# Processing Record 13 of Set 12 | monywa
# Processing Record 14 of Set 12 | umm kaddadah
# Processing Record 15 of Set 12 | pizarro
# Processing Record 16 of Set 12 | wegorzewo
# Processing Record 17 of Set 12 | auki
# Processing Record 18 of Set 12 | okato
# Processing Record 19 of Set 12 | howard
# Processing Record 20 of Set 12 | mahibadhoo
# Processing Record 21 of Set 12 | malyye derbety
# Processing Record 22 of Set 12 | liling
# Processing Record 23 of Set 12 | birjand
# Processing Record 24 of Set 12 | la sarre
# Processing Record 25 of Set 12 | mulbagal
# Processing Record 26 of Set 12 | port augusta
# Processing Record 27 of Set 12 | naze
# Processing Record 28 of Set 12 | marsaxlokk
# Processing Record 29 of Set 12 | los llanos de aridane
# Processing Record 30 of Set 12 | suntar
# Processing Record 31 of Set 12 | wajid
# Processing Record 32 of Set 12 | simbahan
# Processing Record 33 of Set 12 | alofi
# Processing Record 34 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 12 | hay river
# Processing Record 36 of Set 12 | broome
# Processing Record 37 of Set 12 | sioux lookout
# Processing Record 38 of Set 12 | myitkyina
# Processing Record 39 of Set 12 | gambela
# Processing Record 40 of Set 12 | san felipe
# Processing Record 41 of Set 12 | batagay-alyta
# Processing Record 42 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 12 | susanino
# Processing Record 44 of Set 12 | palmerston
# Processing Record 45 of Set 12 | shubarkuduk
# Processing Record 46 of Set 12 | omsukchan
# Processing Record 47 of Set 12 | nabul
# City not found. Skipping...
# Processing Record 48 of Set 12 | puerto ayacucho
# Processing Record 49 of Set 12 | seymchan
# Processing Record 50 of Set 12 | luanda
# Processing Record 1 of Set 13 | alta floresta
# Processing Record 2 of Set 13 | chizhou
# Processing Record 3 of Set 13 | barra
# Processing Record 4 of Set 13 | bayir
# Processing Record 5 of Set 13 | ternate
# Processing Record 6 of Set 13 | nantucket
# Processing Record 7 of Set 13 | amritsar
# Processing Record 8 of Set 13 | oberkirch
# Processing Record 9 of Set 13 | kuzhenkino
# Processing Record 10 of Set 13 | dalnerechensk
# Processing Record 11 of Set 13 | honningsvag
# Processing Record 12 of Set 13 | wynyard
# Processing Record 13 of Set 13 | atocha
# Processing Record 14 of Set 13 | sistranda
# Processing Record 15 of Set 13 | rawson
# Processing Record 16 of Set 13 | surab
# Processing Record 17 of Set 13 | xai-xai
# Processing Record 18 of Set 13 | morondava
# Processing Record 19 of Set 13 | uvat
# Processing Record 20 of Set 13 | baykit
# Processing Record 21 of Set 13 | najran
# Processing Record 22 of Set 13 | apiai
# Processing Record 23 of Set 13 | ovsyanka
# Processing Record 24 of Set 13 | alice springs
# Processing Record 25 of Set 13 | maumere
# Processing Record 26 of Set 13 | linxia
# Processing Record 27 of Set 13 | scottsbluff
# Processing Record 28 of Set 13 | wilmington island
# Processing Record 29 of Set 13 | seoul
# Processing Record 30 of Set 13 | komatipoort
# Processing Record 31 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 32 of Set 13 | hanzhong
# Processing Record 33 of Set 13 | novo aripuana
# Processing Record 34 of Set 13 | oktyabrskiy
# Processing Record 35 of Set 13 | oussouye
# Processing Record 36 of Set 13 | itoman
# Processing Record 37 of Set 13 | lodja
# Processing Record 38 of Set 13 | awassa
# Processing Record 39 of Set 13 | marshfield
# Processing Record 40 of Set 13 | atasu
# Processing Record 41 of Set 13 | pochutla
# Processing Record 42 of Set 13 | santiago del estero
# Processing Record 43 of Set 13 | ordzhonikidze
# Processing Record 44 of Set 13 | wladyslawowo
# Processing Record 45 of Set 13 | lesnoy
# Processing Record 46 of Set 13 | qena
# Processing Record 47 of Set 13 | chemax
# Processing Record 48 of Set 13 | viedma
# Processing Record 49 of Set 13 | kavali
# Processing Record 50 of Set 13 | murray bridge
# Processing Record 1 of Set 14 | ahipara
# Processing Record 2 of Set 14 | vestmannaeyjar
# Processing Record 3 of Set 14 | banda aceh
# Processing Record 4 of Set 14 | camacupa
# Processing Record 5 of Set 14 | dunhua
# Processing Record 6 of Set 14 | zeya
# Processing Record 7 of Set 14 | mayor pablo lagerenza
# Processing Record 8 of Set 14 | goderich
# Processing Record 9 of Set 14 | yeniseysk
# Processing Record 10 of Set 14 | taraz
# Processing Record 11 of Set 14 | orlik
# Processing Record 12 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | manta
# Processing Record 14 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 14 | isabela
# Processing Record 16 of Set 14 | monrovia
# Processing Record 17 of Set 14 | stralsund
# Processing Record 18 of Set 14 | tlacotepec
# Processing Record 19 of Set 14 | pangkalanbuun
# Processing Record 20 of Set 14 | qandala
# Processing Record 21 of Set 14 | sokolka
# Processing Record 22 of Set 14 | te anau
# Processing Record 23 of Set 14 | kyrylivka
# Processing Record 24 of Set 14 | tabou
# Processing Record 25 of Set 14 | novobelokatay
# Processing Record 26 of Set 14 | oktyabrskoye
# Processing Record 27 of Set 14 | kuppam
# Processing Record 28 of Set 14 | sarapulka
# Processing Record 29 of Set 14 | muisne
# Processing Record 30 of Set 14 | gunjur
# Processing Record 31 of Set 14 | warkworth
# Processing Record 32 of Set 14 | magangue
# Processing Record 33 of Set 14 | monte patria
# Processing Record 34 of Set 14 | raudeberg
# Processing Record 35 of Set 14 | gimli
# Processing Record 36 of Set 14 | marawi
# Processing Record 37 of Set 14 | gibara
# Processing Record 38 of Set 14 | mustasaari
# Processing Record 39 of Set 14 | colares
# Processing Record 40 of Set 14 | zabaykalsk
# Processing Record 41 of Set 14 | rimbey
# Processing Record 42 of Set 14 | chernenko
# Processing Record 43 of Set 14 | tucurui
# Processing Record 44 of Set 14 | lengshuitan
# Processing Record 45 of Set 14 | mazulskiy
# City not found. Skipping...
# Processing Record 46 of Set 14 | sept-iles
# Processing Record 47 of Set 14 | flin flon
# Processing Record 48 of Set 14 | marsa matruh
# Processing Record 49 of Set 14 | lahat
# Processing Record 50 of Set 14 | clovis
# Processing Record 1 of Set 15 | melilla
# Processing Record 2 of Set 15 | antibes
# Processing Record 3 of Set 15 | termoli
# Processing Record 4 of Set 15 | warrnambool
# Processing Record 5 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 15 | binga
# Processing Record 7 of Set 15 | pagondas
# City not found. Skipping...
# Processing Record 8 of Set 15 | arukula
# Processing Record 9 of Set 15 | bilibino
# Processing Record 10 of Set 15 | kindersley
# Processing Record 11 of Set 15 | dvinskoy
# Processing Record 12 of Set 15 | qaqortoq
# Processing Record 13 of Set 15 | klimovo
# Processing Record 14 of Set 15 | broken hill
# Processing Record 15 of Set 15 | manama
# Processing Record 16 of Set 15 | cayenne
# Processing Record 17 of Set 15 | vieste
# Processing Record 18 of Set 15 | lipovtsy
# Processing Record 19 of Set 15 | haines junction
# Processing Record 20 of Set 15 | yarada
# Processing Record 21 of Set 15 | sorbhog
# Processing Record 22 of Set 15 | zhigansk
# Processing Record 23 of Set 15 | orodara
# Processing Record 24 of Set 15 | dzhebariki-khaya
# Processing Record 25 of Set 15 | menzelinsk
# Processing Record 26 of Set 15 | darhan
# Processing Record 27 of Set 15 | ampanihy
# Processing Record 28 of Set 15 | semey
# Processing Record 29 of Set 15 | bud
# Processing Record 30 of Set 15 | kieta
# Processing Record 31 of Set 15 | mollendo
# Processing Record 32 of Set 15 | havoysund
# Processing Record 33 of Set 15 | jiangyou
# Processing Record 34 of Set 15 | pali
# Processing Record 35 of Set 15 | ust-nera
# Processing Record 36 of Set 15 | bolshaya glushitsa
# Processing Record 37 of Set 15 | singkawang
# Processing Record 38 of Set 15 | benjamin aceval
# Processing Record 39 of Set 15 | badou
# Processing Record 40 of Set 15 | lakes entrance
# Processing Record 41 of Set 15 | neiafu
# Processing Record 42 of Set 15 | shingu
# Processing Record 43 of Set 15 | belmonte
# Processing Record 44 of Set 15 | matara
# Processing Record 45 of Set 15 | tomatlan
# Processing Record 46 of Set 15 | yumen
# Processing Record 47 of Set 15 | altamira
# Processing Record 48 of Set 15 | pishva
# Processing Record 49 of Set 15 | nelson bay
# Processing Record 50 of Set 15 | alyangula
# Processing Record 1 of Set 16 | burica
# City not found. Skipping...
# Processing Record 2 of Set 16 | mount isa
# Processing Record 3 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 16 | fayaoue
# Processing Record 5 of Set 16 | edson
# Processing Record 6 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 16 | nexo
# Processing Record 8 of Set 16 | bubaque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country  Cloudiness  Humidity      Lat       Lng  Max Temp  \
# 0  Pacific Grove      US           0        74  36.6177 -121.9166     61.56
# 1      Cape Town      ZA           0        36 -33.9258   18.4232     77.11
# 2        Iqaluit      CA         100        86  63.7506  -68.5145     20.93
# 3         Hobart      AU          20        87 -42.8794  147.3294     55.06
# 4        Ibipeba      BR           5        35 -11.6408  -42.0111     83.46
# 5         Jieshi      CN           0        73  22.8134  115.8257     69.53
# 6   Norman Wells      CA          20        68  65.2820 -126.8329     19.44
# 7           Teya      RU         100        96  60.3778   92.6267     25.95
# 8   Port Hedland      AU           9        79 -20.3167  118.5667     84.25
# 9        Mataura      NZ         100        73 -46.1927  168.8643     50.18
#
#    Wind Speed Weather Description
# 0        4.00           clear sky
# 1       17.27           clear sky
# 2       10.36          light snow
# 3        6.91          few clouds
# 4        8.03           clear sky
# 5       17.16           clear sky
# 6        5.75          few clouds
# 7        1.90     overcast clouds
# 8       11.50           clear sky
# 9        4.63     overcast clouds

# %%
#Reordering the columns
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp", 
                    "Humidity", "Cloudiness", "Wind Speed","Weather Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pacific Grove      US  36.6177 -121.9166     61.56        74           0
# 1      Cape Town      ZA -33.9258   18.4232     77.11        36           0
# 2        Iqaluit      CA  63.7506  -68.5145     20.93        86         100
# 3         Hobart      AU -42.8794  147.3294     55.06        87          20
# 4        Ibipeba      BR -11.6408  -42.0111     83.46        35           5
# 5         Jieshi      CN  22.8134  115.8257     69.53        73           0
# 6   Norman Wells      CA  65.2820 -126.8329     19.44        68          20
# 7           Teya      RU  60.3778   92.6267     25.95        96         100
# 8   Port Hedland      AU -20.3167  118.5667     84.25        79           9
# 9        Mataura      NZ -46.1927  168.8643     50.18        73         100
#
#    Wind Speed Weather Description
# 0        4.00           clear sky
# 1       17.27           clear sky
# 2       10.36          light snow
# 3        6.91          few clouds
# 4        8.03           clear sky
# 5       17.16           clear sky
# 6        5.75          few clouds
# 7        1.90     overcast clouds
# 8       11.50           clear sky
# 9        4.63     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
